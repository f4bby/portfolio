# %%
from src.fx import get_fx_to_eur


usd = get_fx_to_eur("USD")
gbp = get_fx_to_eur("GBP")
chf = get_fx_to_eur("CHF")
eur = get_fx_to_eur("EUR")

print(f"1 USD = {usd:.4f} EUR")
print(f"1 GBP = {gbp:.4f} EUR")
print(f"1 CHF = {chf:.4f} EUR")
print(f"1 EUR = {eur:.4f} EUR")
# Out:
# 1 USD = 0.8645 EUR
# 1 GBP = 1.1703 EUR
# 1 CHF = 1.0650 EUR
# 1 EUR = 1.0000 EUR
